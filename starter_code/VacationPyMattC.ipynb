# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import cartopy
import geoviews

# Import API key
from api_keys import geoapify_key
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# C:\Users\matth\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0          Greymouth -42.4667  171.2000     10.82        88
# 1        1        Nova Sintra  14.8667  -24.7167     25.57        73
# 2        2  Port-aux-Français -49.3500   70.2167      2.99        88
# 3        3            Birjand  32.8663   59.2211     12.26        26
# 4        4            Cologne  50.9333    6.9500      8.81        88
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        2.92      NZ  1697491952
# 1          37        3.71      CV  1697491953
# 2          87       12.57      TF  1697491952
# 3           0        5.14      IR  1697491953
# 4           0        2.06      DE  1697491310

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 600,
    frame_height = 500,
    scale = 0.4,
    size = "Humidity",
    color = "City",
)
# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df[(city_data_df["Cloudiness"] < 60) & (city_data_df["Max Temp"] < 30) & (city_data_df["Humidity"] < 40)]

# Drop any rows with null values
ideal_df = ideal_df.dropna()

# Display sample data
ideal_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 3          3         Birjand  32.8663   59.2211     12.26        26
# 68        68        Shiprock  36.7855 -108.6870     25.19        15
# 75        75       Er Regueb  34.8593    9.7865     22.94        30
# 83        83          Béchar  31.6167   -2.2167     25.18        22
# 88        88       Dzhangala  49.2167   50.3333     11.06        35
# 89        89        Ghadames  30.1337    9.5007     24.35        18
# 145      145           Khāsh  28.2211   61.2158     18.08        22
# 149      149  Puerto Deseado -47.7503  -65.8938     14.20        39
# 157      157          At Tāj  24.2049   23.2857     21.40        27
# 169      169        Ad Dilam  23.9915   47.1627     29.23        14
# 213      213          Laguna  38.4210 -121.4238     29.08        39
# 264      264         Arraias -12.9288  -46.9437     29.25        17
# 276      276    San Patricio  28.0170  -97.5169     24.92        32
# 301      301  Villa Mercedes -33.6757  -65.4578     22.53        17
# 305      305           Aswān  24.0934   32.9070     24.94        30
# 313      313           Ha'il  27.5219   41.6907     23.01        38
# 320      320    Port Hedland -20.3167  118.5667     24.03        11
# 341      341       Sebastian  35.1668  -94.2669     20.31        35
# 365      365         Gazojak  41.1875   61.4036     12.06        29
# 366      366      Letlhakeng -24.0944   25.0298     20.19        22
# 377      377    Tamanghasset  22.7850    5.5228     21.95        20
# 382      382         Tindouf  27.6711   -8.1474     28.25        20
# 393      393         Emerald -23.5333  148.1667     24.63        25
# 398      398     Al Khārijah  25.4514   30.5464     22.16        39
# 402      402    Al Arţāwīyah  26.5053   45.3444     22.67        32
# 435      435         Kashgar  39.4547   75.9797     16.56        27
# 470      470     Zuni Pueblo  35.0725 -108.8506     25.35        10
# 473      473        Mezzouna  34.5776    9.8419     22.57        36
# 474      474          Potosí -19.5836  -65.7531     18.48        24
# 477      477            Brak  27.5496   14.2714     23.14        20
# 480      480       Mount Isa -20.7333  139.5000     21.87        26
# 498      498     Xique Xique -10.8217  -42.7311     29.72        35
# 508      508      Williamson  30.6502  -97.6003     24.06        34
# 531      531        Karratha -20.7377  116.8463     26.47        21
# 538      538        Santiago -33.4569  -70.6483     24.08        33
# 556      556   South Hedland -20.4089  118.5983     23.96        11
#
#      Cloudiness  Wind Speed Country        Date
# 3             0        5.14      IR  1697491953
# 68            3        1.26      US  1697491966
# 75            0        3.55      TN  1697491967
# 83            0        2.57      DZ  1697491969
# 88           17        7.97      KZ  1697491969
# 89            3        3.27      LY  1697491970
# 145           0        1.59      IR  1697491980
# 149           6        3.06      AR  1697491981
# 157           0        3.85      LY  1697491982
# 169           0        4.97      SA  1697491985
# 213           0        2.06      US  1697491458
# 264           1        2.69      BR  1697492003
# 276           0        5.67      US  1697491581
# 301           0        7.45      AR  1697492011
# 305           0        6.45      EG  1697491567
# 313           0        3.09      SA  1697492014
# 320           0        4.12      AU  1697491584
# 341           0        3.93      US  1697492019
# 365           0        4.48      TM  1697492024
# 366           0        3.06      BW  1697492024
# 377          20        1.54      DZ  1697491610
# 382          40        3.09      DZ  1697492027
# 393           2        9.17      AU  1697492000
# 398           0        2.95      EG  1697492031
# 402           0        4.10      SA  1697492031
# 435          40        2.00      CN  1697491611
# 470           0        3.40      US  1697491937
# 473           0        3.10      TN  1697492046
# 474          40        6.17      BO  1697492046
# 477           0        3.05      LY  1697492047
# 480           5        7.72      AU  1697491464
# 498           2        4.52      BR  1697492051
# 508           0        7.20      US  1697491758
# 531           0        5.43      AU  1697492057
# 538           0        6.69      CL  1697491955
# 556           0        4.12      AU  1697492063

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 3           Birjand      IR  32.8663   59.2211        26
# 68         Shiprock      US  36.7855 -108.6870        15
# 75        Er Regueb      TN  34.8593    9.7865        30
# 83           Béchar      DZ  31.6167   -2.2167        22
# 88        Dzhangala      KZ  49.2167   50.3333        35
# 89         Ghadames      LY  30.1337    9.5007        18
# 145           Khāsh      IR  28.2211   61.2158        22
# 149  Puerto Deseado      AR -47.7503  -65.8938        39
# 157          At Tāj      LY  24.2049   23.2857        27
# 169        Ad Dilam      SA  23.9915   47.1627        14
# 213          Laguna      US  38.4210 -121.4238        39
# 264         Arraias      BR -12.9288  -46.9437        17
# 276    San Patricio      US  28.0170  -97.5169        32
# 301  Villa Mercedes      AR -33.6757  -65.4578        17
# 305           Aswān      EG  24.0934   32.9070        30
# 313           Ha'il      SA  27.5219   41.6907        38
# 320    Port Hedland      AU -20.3167  118.5667        11
# 341       Sebastian      US  35.1668  -94.2669        35
# 365         Gazojak      TM  41.1875   61.4036        29
# 366      Letlhakeng      BW -24.0944   25.0298        22
# 377    Tamanghasset      DZ  22.7850    5.5228        20
# 382         Tindouf      DZ  27.6711   -8.1474        20
# 393         Emerald      AU -23.5333  148.1667        25
# 398     Al Khārijah      EG  25.4514   30.5464        39
# 402    Al Arţāwīyah      SA  26.5053   45.3444        32
# 435         Kashgar      CN  39.4547   75.9797        27
# 470     Zuni Pueblo      US  35.0725 -108.8506        10
# 473        Mezzouna      TN  34.5776    9.8419        36
# 474          Potosí      BO -19.5836  -65.7531        24
# 477            Brak      LY  27.5496   14.2714        20
# 480       Mount Isa      AU -20.7333  139.5000        26
# 498     Xique Xique      BR -10.8217  -42.7311        35
# 508      Williamson      US  30.6502  -97.6003        34
# 531        Karratha      AU -20.7377  116.8463        21
# 538        Santiago      CL -33.4569  -70.6483        33
# 556   South Hedland      AU -20.4089  118.5983        11

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 1
categories = "accommodation.hotel"
params = {
    "limit":limit,
    "apiKey": geoapify_key,
    "categories": categories,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    long = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filters"] = f"cirlce:{long},{lat},{radius}"
    params["bias"] = f"proximity:{long},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Birjand - nearest hotel: مهمانسرای جهانگردی بیرجند
# Shiprock - nearest hotel: Kokopelli's Cave
# Er Regueb - nearest hotel: فندق بن محمود
# Béchar - nearest hotel: Hôtel Madania
# Dzhangala - nearest hotel: Общежитие Жангалинского ЛПУ
# Ghadames - nearest hotel: فندق عين الفارس
# Khāsh - nearest hotel: هتل قصِر
# Puerto Deseado - nearest hotel: Los Olmos
# At Tāj - nearest hotel: بلوك حسن البرغثي
# Ad Dilam - nearest hotel: شقق فندقية
# Laguna - nearest hotel: Holiday Inn Express & Suites
# Arraias - nearest hotel: No hotel found
# San Patricio - nearest hotel: Best Western Plus
# Villa Mercedes - nearest hotel: La Valle
# Aswān - nearest hotel: Yaseen hotel
# Ha'il - nearest hotel: فندق كلاسيك
# Port Hedland - nearest hotel: The Esplanade Hotel
# Sebastian - nearest hotel: No hotel found
# Gazojak - nearest hotel: Жайхун
# Letlhakeng - nearest hotel: Mokala Lodge & Teemane Casino
# Tamanghasset - nearest hotel: فندق الأمان
# Tindouf - nearest hotel: محمد بوسبي
# Emerald - nearest hotel: Emerald Central Hotel
# Al Khārijah - nearest hotel: Kharga Hotel
# Al Arţāwīyah - nearest hotel: فندق الفالح
# Kashgar - nearest hotel: 深航国际酒店
# Zuni Pueblo - nearest hotel: Hampton Inn Gallup-West
# Mezzouna - nearest hotel: فندق بن محمود
# Potosí - nearest hotel: Hotel Tarija
# Brak - nearest hotel: فندق براك السياحي
# Mount Isa - nearest hotel: Ibis Styles
# Xique Xique - nearest hotel: Hotel J. Macedo
# Williamson - nearest hotel: Holiday Inn Express & Suites Georgetown
# Karratha - nearest hotel: Karratha International Hotel
# Santiago - nearest hotel: apart arturo prat
# South Hedland - nearest hotel: Port Haven
#                City Country      Lat       Lng  Humidity  \
# 3           Birjand      IR  32.8663   59.2211        26
# 68         Shiprock      US  36.7855 -108.6870        15
# 75        Er Regueb      TN  34.8593    9.7865        30
# 83           Béchar      DZ  31.6167   -2.2167        22
# 88        Dzhangala      KZ  49.2167   50.3333        35
# 89         Ghadames      LY  30.1337    9.5007        18
# 145           Khāsh      IR  28.2211   61.2158        22
# 149  Puerto Deseado      AR -47.7503  -65.8938        39
# 157          At Tāj      LY  24.2049   23.2857        27
# 169        Ad Dilam      SA  23.9915   47.1627        14
# 213          Laguna      US  38.4210 -121.4238        39
# 264         Arraias      BR -12.9288  -46.9437        17
# 276    San Patricio      US  28.0170  -97.5169        32
# 301  Villa Mercedes      AR -33.6757  -65.4578        17
# 305           Aswān      EG  24.0934   32.9070        30
# 313           Ha'il      SA  27.5219   41.6907        38
# 320    Port Hedland      AU -20.3167  118.5667        11
# 341       Sebastian      US  35.1668  -94.2669        35
# 365         Gazojak      TM  41.1875   61.4036        29
# 366      Letlhakeng      BW -24.0944   25.0298        22
# 377    Tamanghasset      DZ  22.7850    5.5228        20
# 382         Tindouf      DZ  27.6711   -8.1474        20
# 393         Emerald      AU -23.5333  148.1667        25
# 398     Al Khārijah      EG  25.4514   30.5464        39
# 402    Al Arţāwīyah      SA  26.5053   45.3444        32
# 435         Kashgar      CN  39.4547   75.9797        27
# 470     Zuni Pueblo      US  35.0725 -108.8506        10
# 473        Mezzouna      TN  34.5776    9.8419        36
# 474          Potosí      BO -19.5836  -65.7531        24
# 477            Brak      LY  27.5496   14.2714        20
# 480       Mount Isa      AU -20.7333  139.5000        26
# 498     Xique Xique      BR -10.8217  -42.7311        35
# 508      Williamson      US  30.6502  -97.6003        34
# 531        Karratha      AU -20.7377  116.8463        21
# 538        Santiago      CL -33.4569  -70.6483        33
# 556   South Hedland      AU -20.4089  118.5983        11
#
#                                   Hotel Name
# 3                  مهمانسرای جهانگردی بیرجند
# 68                          Kokopelli's Cave
# 75                             فندق بن محمود
# 83                             Hôtel Madania
# 88               Общежитие Жангалинского ЛПУ
# 89                           فندق عين الفارس
# 145                                 هتل قصِر
# 149                                Los Olmos
# 157                         بلوك حسن البرغثي
# 169                               شقق فندقية
# 213             Holiday Inn Express & Suites
# 264                           No hotel found
# 276                        Best Western Plus
# 301                                 La Valle
# 305                             Yaseen hotel
# 313                              فندق كلاسيك
# 320                      The Esplanade Hotel
# 341                           No hotel found
# 365                                   Жайхун
# 366            Mokala Lodge & Teemane Casino
# 377                              فندق الأمان
# 382                               محمد بوسبي
# 393                    Emerald Central Hotel
# 398                             Kharga Hotel
# 402                              فندق الفالح
# 435                                   深航国际酒店
# 470                  Hampton Inn Gallup-West
# 473                            فندق بن محمود
# 474                             Hotel Tarija
# 477                        فندق براك السياحي
# 480                              Ibis Styles
# 498                          Hotel J. Macedo
# 508  Holiday Inn Express & Suites Georgetown
# 531             Karratha International Hotel
# 538                        apart arturo prat
# 556                               Port Haven

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_ideal = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 600,
    frame_height = 500,
    scale = 0.4,
    size = "Humidity",
    color = "City",
    hover_cols=["County","Hotel Name"]
)

# Display the map
map_plot_ideal
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)
